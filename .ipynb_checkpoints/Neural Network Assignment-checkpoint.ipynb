# %% [markdown]
# ### Project: Create a neural network class
#
# ---
#
# Based on previous code examples, develop a neural network class that is able to classify any dataset provided. The class should create objects based on the desired network architecture:
#
# 1. Number of inputs
# 2. Number of hidden layers
# 3. Number of neurons per layer
# 4. Number of outputs
# 5. Learning rate
#
# The class must have the train, and predict functions.
#
# Test the neural network class on the datasets provided below: Use the input data to train the network, and then pass new inputs to predict on. Print the expected label and the predicted label for the input you used. Print the accuracy of the training after predicting on different inputs.
#
# Use matplotlib to plot the error that the train method generates.
#
# **Don't forget to install Keras and tensorflow in your environment!**
#
# ---

# %% [markdown]
# ### Import the needed Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# Needed for the mnist data
from keras.datasets import mnist
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Define the class

# %%
import itertools

def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = itertools.tee(iterable)
    next(b, None)
    return zip(a, b)

class NeuralNetwork:

    def __init__(self, architecture, alpha):
        '''
            layers: List of integers which represents the architecture of the network.
            alpha:  Learning rate.
        '''
        # TODO: Initialize the list of weights matrices, then store
        # the network architecture and learning rate
        self.alpha = alpha
        self.layers = architecture
        
        np.random.seed(42)
        
        self.weights0 = np.random.randn(architecture[0], architecture[1]) # 2,3
        self.weights1 = np.random.randn(2,1) # 3,3
        
        self.b0 = np.random.randn(2) # 3
        self.b1 = np.random.randn(1) # 3

        pass
    
            
    def __repr__(self): 
        # construct and return a string that represents the network 
        # architecture 
        return "NeuralNetwork: {}".format( "-".join(str(l) for l in self.layers))

    def softmax(self,X):  
        # applies the softmax function to a set of values
        
        expX = np.exp(X)
        return expX / expX.sum(axis=1, keepdims=True)
        
    def sigmoid(self, x):
        # the sigmoid for a given input value
        
        return 1.0 / (1.0 + np.exp(-x))
    
    def sigmoid_deriv(self, x):
        # the derivative of the sigmoid
        
        return x * (1 - x)
    
    def predict(self, inputs):
        # TODO: Define the predict function
        pass
        
    def train(self, inputs, labels, epochs = 1000, displayUpdate = 100):
        # TODO: Define the training step for the network. It should include the forward and back propagation
        # steps, the updating of the weights, and it should print the error every 'displayUpdate' epochs
        # It must return the errors so that they can be displayed with matplotlib
        
        errors = []
        for epoch in range(epochs):
            # Forwards
            level0 = inputs
            level1 = self.sigmoid(np.dot(level0, self.weights0)+self.b0)
            level2 = self.sigmoid(np.dot(level1, self.weights1)+self.b1)
            
            level2_error = labels - level2
            
            level2_delta = level2_error * self.sigmoid_deriv(level2)
            
            level1_error = np.dot(level2_delta, self.weights1.T)
            level1_delta = level1_error * self.sigmoid_deriv(level1)
            
            b0_delta = np.sum(level1_delta)    
            b1_delta = np.sum(level2_delta)
            
            self.weights1 += np.dot(level1.T, level2_delta) * self.alpha
            self.weights0 += np.dot(level0.T, level1_delta) * self.alpha

            self.b1 += b1_delta * self.alpha
            self.b0 += b0_delta * self.alpha
            errors.append(np.mean(np.abs(level2_error)))
        return errors

# %% [markdown]
# ### Test datasets

# %% [markdown]
# #### XOR

# %%
# input dataset
XOR_inputs = np.array([  
                [0,0],
                [0,1],
                [1,0],
                [1,1]
            ])

# labels dataset            
XOR_labels = np.array([[0,1,1,0]]).T
print("XOR_inputs",XOR_inputs.shape)
print("XOR_labels",XOR_labels.shape)
# Out:
# XOR_inputs (4, 2)
# XOR_labels (4, 1)

# %%
#TODO: Test the class with the XOR data
inputs = XOR_inputs.shape[1]
layer1 = 2
output = 2
alpha = 0.3
network = NeuralNetwork([inputs,layer1,output],alpha)
errors = network.train(XOR_inputs, XOR_labels, 10000)
plt.plot(errors)
#plt.plot(errors)
#print(a.predict(XOR_inputs[3]))
#a.evaluate(XOR_inputs, XOR_labels)

# %% [markdown]
# #### Multiple classes

# %%
# Creates the data points for each class
class_1 = np.random.randn(700, 2) + np.array([0, -3])  
class_2 = np.random.randn(700, 2) + np.array([3, 3])  
class_3 = np.random.randn(700, 2) + np.array([-3, 3])

feature_set = np.vstack([class_1, class_2, class_3])

labels = np.array([0]*700 + [1]*700 + [2]*700)

one_hot_labels = np.zeros((2100, 3))

for i in range(2100):  
    one_hot_labels[i, labels[i]] = 1

plt.figure(figsize=(10,10))  
plt.scatter(feature_set[:,0], feature_set[:,1], c=labels, s=30, alpha=0.5)  
plt.show()

# %%
#TODO: Test the class with the multiple classes data
inputs = feature_set.shape[1]
layer1 = 3
output = 3
alpha = 0.1
print("inputs",inputs)
network = NeuralNetwork([inputs,layer1,output],alpha)
errors = network.train(feature_set, one_hot_labels, 10000)
plt.plot(errors)
# Out:
# feature_set.shape[1] 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-1b2bcb729f58> in <module>
#       6 network = NeuralNetwork([inputs,layer1,output],alpha)
#       7 print("feature_set.shape[1]",feature_set.shape[1])
# ----> 8 errors = network.train(feature_set, one_hot_labels, 10000)
#       9 plt.plot(errors)
#
# <ipython-input-20-3600e6dfba4f> in train(self, inputs, labels, epochs, displayUpdate)
#      64             # Forwards
#      65             level0 = inputs
# ---> 66             level1 = self.sigmoid(np.dot(level0, self.weights0)+self.b0)
#      67             level2 = self.sigmoid(np.dot(level1, self.weights1)+self.b1)
#      68
#
# ValueError: operands could not be broadcast together with shapes (2100,10) (2,)

# %% [markdown]
# #### On the mnist data set
#
# ---
# Train the network to classify hand drawn digits.
#
# For this data set, if the training step is taking too long, you can try to adjust the architecture of the network to have fewer layers, or you could try to train it with fewer input. The data has already been loaded and preprocesed so that it can be used with the network.
#
# ---

# %%
# Load the train and test data from the mnist data set
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Plot a sample data point
plt.title("Label: " + str(train_labels[0]))
plt.imshow(train_images[0], cmap="gray")

# %%
# Standardize the data

# Flatten the images
train_images = train_images.reshape((60000, 28 * 28))
# turn values from 0-255 to 0-1
train_images = train_images.astype('float32') / 255 

test_images = test_images.reshape((10000, 28 * 28)) 
test_images = test_images.astype('float32') / 255

# Create one hot encoding for the labels
train_labels = to_categorical(train_labels) 
test_labels = to_categorical(test_labels)

# %%
# TODO: Test the class with the mnist data. Test the training of the network with the test_images data, and 
# record the accuracy of the classification.
c = NeuralNetwork([ 784, 10], 0.5)
print(c)
errors = c.train(train_images, train_labels, 1000, 10)
plt.plot(errors)
c.evaluate(test_images, test_labels)
# Out:
# self.outputs [array(784), array(10)]
# self.weights [0, array([[0.83754453, 0.20082693, 0.03862657, ..., 0.33441429, 0.32863505,
#         0.57889755],
#        [0.16169537, 0.2974322 , 0.90968381, ..., 0.84164786, 0.9148154 ,
#         0.86334872],
#        [0.99159291, 0.06226105, 0.49366154, ..., 0.55487385, 0.18058911,
#         0.13207593],
#        ...,
#        [0.1052905 , 0.6673368 , 0.70591897, ..., 0.15701116, 0.42565575,
#         0.03064953],
#        [0.32708589, 0.57524189, 0.87400222, ..., 0.8101273 , 0.54825292,
#         0.47689979],
#        [0.46494021, 0.64498963, 0.47884515, ..., 0.49295855, 0.17221391,
#         0.46420515]])]
# self.bs [0, array([[0.86268052, 0.83371338, 0.52947076, 0.79768297, 0.90472371,
#         0.91726501, 0.84183668, 0.12765809, 0.27098897, 0.42177068]])]
# NeuralNetwork: 784-10
# Error [350]: 0.058389451540790036

# %% [markdown]
# After predicting on the *test_images*, use matplotlib to display some of the images that were not correctly classified. Then, answer the following questions:
#
# 1. **Why do you think those were incorrectly classified?**
# 2. **What could you try doing to improve the classification accuracy?**
